# %%
import numpy as np
import pandas as pd

dados=pd.read_csv('/content/drive/MyDrive/arquivos_aula/heart.csv',sep=',',encoding='iso-8859-1')

# %%
dados.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
dados.tail()

# %%
dados.shape
# Out:
# (918, 12)

# %%
dados['Age'].value_counts().sort_index()

# %%
import plotly.express as px

# %%
hist_1=px.histogram(dados,x="Age", nbins=50)
hist_1.update_layout(width=600,height=400,title_text='Distribuiçâo das idades')
hist_1.show()

# %%
import seaborn as sns

# %%
sns.histplot(dados, x='Age', bins=50, color='orange',kde=True,stat="count")

# %%
dados['Sex'].value_counts()

# %%
sns.countplot(x='Sex',data=dados);

# %%
dados['ChestPainType'].value_counts()

# %%
sns.countplot(x='ChestPainType',data=dados);

# %%
dados.RestingBP.value_counts().sort_index()

# %%
sns.histplot(dados,x='RestingBP',bins=30, color="red",kde=True, stat='count' );

# %%
dados.Cholesterol.value_counts().sort_index()

# %%
sns.histplot(dados,x='Cholesterol',bins=40,color='orange', kde=True,stat='count')

# %%
dados.FastingBS.value_counts()

# %%
sns.countplot(x="FastingBS",data=dados);

# %%
dados.RestingECG.value_counts()

# %%
sns.countplot(x='RestingECG',data=dados)

# %%
dados.MaxHR.value_counts().sort_index()

# %%
sns.histplot(dados,x='MaxHR',bins=40,color='orange', kde=True,stat='count');

# %%
dados['ExerciseAngina'].value_counts()

# %%
px.pie(dados, 'ExerciseAngina')

# %%
dados.Oldpeak.value_counts().sort_index()

# %%
sns.histplot(dados,x='Oldpeak',bins=30,color="orange",kde=True, stat='count');

# %%
dados.ST_Slope.value_counts()

# %%
px.pie(dados,'ST_Slope')

# %%
dados.HeartDisease.value_counts()

# %%
px.pie(dados,'HeartDisease')

# %%
dados.isnull().sum()# ver se tem algum lugar sem precher

# %%
dados2=dados.dropna() #excluir valores missing

# %%
dados2.shape
# Out:
# (918, 12)

# %%
dados2.isnull().sum()

# %%
#subistuir os valores missing pela media='mean"
dados2.Age.fillna(dados.Age.mean(),inplace=True)

# %%
#subistuir os valores missing por qualquer outro valor 
dados.Age.fillna(10,inplace=True)

# %%
dados.describe()

# %%
dados.mode()

# %% [markdown]
# **Tratando valores Incoerentes**

# %% [markdown]
# **Excluindo Registro com pressão Zero**

# %%
dados2.RestingBP.value_counts().sort_index()
# Out:
# 0       1
# 80      1
# 92      1
# 94      2
# 95      6
#        ..
# 180    12
# 185     1
# 190     2
# 192     1
# 200     4
# Name: RestingBP, Length: 67, dtype: int64

# %%
# para substuir ou puchar dados especificos
#dados2=dados.loc[dados.RestingBP!=0]

# %%
dados2.RestingBP.mean()
# Out:
# 132.39651416122004

# %%
dados2.RestingBP.replace(0,np.NaN,inplace=True)

# %%
dados.isnull().sum()

# %%
dados2.RestingBP.mean()
# Out:
# 132.54089422028352

# %%
dados2.RestingBP.fillna(dados2.RestingBP.mean(),inplace=True)

# %%
dados2.shape

# %%
dados2.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.540894   244.635389    0.233115  136.809368
# std      9.432617   17.989932    53.318029    0.423046   25.460334
# min     28.000000   80.000000    85.000000    0.000000   60.000000
# 25%     47.000000  120.000000   214.000000    0.000000  120.000000
# 50%     54.000000  130.000000   244.635389    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# **Cholesterol**

# %%
dados2.Cholesterol.value_counts()

# %%
dados2.Cholesterol.mean()

# %%
dados2.Cholesterol.replace(0,np.NaN,inplace=True)

# %%
dados2.isnull().sum()

# %%
dados2.Cholesterol.mean()

# %%
dados2.Cholesterol.fillna(dados2.Cholesterol.mean(),inplace=True)

# %%
dados2.mode()

# %%
sns.histplot(dados2,x='Cholesterol',bins=30,color='orange',kde=True,stat="count")

# %% [markdown]
# **Analise de Outliers negrito negrito**

# %%
dados.head(0)
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
px.box(dados2,y='Age')

# %%
px.box(dados2,y='RestingBP')

# %%
px.box(dados2,y='Cholesterol')

# %% [markdown]
# **Salvando (Exportando) o [DataFrame](https://) Tratado**

# %%
dados2.to_csv('heart_tratadoa.Csv',sep=';',encoding='utf-8', index=False)
